# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxMing919/113-2_Generative-AI_NTNU/blob/main/%E7%94%9F%E6%88%90%E5%BC%8FAI_0304%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **模型來源** :
# https://www.thiswaifudoesnotexist.net/

# %% [markdown]
# # **為什麼現在較沒有人在使用GAN來生圖？**
#
# *   訓練不穩定 : 生成器與判別器需要很好的同步，很難使其生成的結果產生收斂。

# %% [markdown]
# ![example-92087.jpg](data:image/jpeg;base64,...)![example-50747.jpg](data:image/jpeg;base64,...)![example-58208.jpg](data:image/jpeg;base64,...)![example-68020.jpg](data:image/jpeg;base64,...)![example-8632.jpg](data:image/jpeg;base64,...)![example-22921.jpg](data:image/jpeg;base64,...)![example-39170.jpg](data:image/jpeg;base64,...)![example-11120.jpg](data:image/jpeg;base64,...)
